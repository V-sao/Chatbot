# %% [markdown]
# <a href="https://colab.research.google.com/github/V-sao/Chatbot/blob/Python/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Import and load the data file

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/Chat bot/intents.json').read()
intents = json.loads(data_file)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %% [markdown]
# ##Preprocess data

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
# lemmatize, lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)

pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']

# %% [markdown]
# ##Create training and testing data

# %%
# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# <ipython-input-18-451aefdaa425>:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %% [markdown]
# ##Build the model

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model 
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 10/10 [==============================] - 1s 4ms/step - loss: 2.2195 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1762 - accuracy: 0.1277
# Epoch 3/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0697 - accuracy: 0.2553
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9273 - accuracy: 0.4043
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8551 - accuracy: 0.3830
# Epoch 6/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7235 - accuracy: 0.5106
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.6390 - accuracy: 0.5319
# Epoch 8/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4841 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2811 - accuracy: 0.6596
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1111 - accuracy: 0.7234
# Epoch 11/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9030 - accuracy: 0.7660
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.9245 - accuracy: 0.8085
# Epoch 13/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7087 - accuracy: 0.8723
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.8134 - accuracy: 0.8511
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6761 - accuracy: 0.8723
# Epoch 16/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.7256 - accuracy: 0.8085
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5575 - accuracy: 0.8936
# Epoch 18/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5020 - accuracy: 0.8936
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4369 - accuracy: 0.8936
# Epoch 20/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5690 - accuracy: 0.8298
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3447 - accuracy: 0.9574
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4930 - accuracy: 0.8936
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4862 - accuracy: 0.8723
# Epoch 24/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3635 - accuracy: 0.9362
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3699 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3573 - accuracy: 0.8936
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3465 - accuracy: 0.8936
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4309 - accuracy: 0.8723
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2831 - accuracy: 0.9574
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3388 - accuracy: 0.9149
# Epoch 31/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2479 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3697 - accuracy: 0.8936
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1882 - accuracy: 0.9362
# Epoch 34/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1472 - accuracy: 1.0000
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2448 - accuracy: 0.9149
# Epoch 36/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2021 - accuracy: 0.9362
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1417 - accuracy: 0.9362
# Epoch 38/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1738 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1392 - accuracy: 0.9787
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1615 - accuracy: 0.9574
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0964 - accuracy: 1.0000
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1140 - accuracy: 0.9787
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1308 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1224 - accuracy: 0.9787
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1217 - accuracy: 0.9574
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0957 - accuracy: 0.9787
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1126 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9574
# Epoch 50/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1065 - accuracy: 0.9574
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1212 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9787
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 1.0000
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0680 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1113 - accuracy: 0.9787
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0733 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 58/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0316 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9574
# Epoch 64/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0709 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1723 - accuracy: 0.9574
# Epoch 68/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1478 - accuracy: 0.9574
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9787
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 73/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9787
# Epoch 74/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 1.0000
# Epoch 76/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0396 - accuracy: 0.9787
# Epoch 78/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 79/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 1.0000
# Epoch 80/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9787
# Epoch 81/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 82/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9787
# Epoch 83/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9787
# Epoch 84/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9574
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 1.0000
# Epoch 90/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9787
# Epoch 91/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0931 - accuracy: 0.9787
# Epoch 92/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0738 - accuracy: 0.9787
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9787
# Epoch 95/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 97/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0657 - accuracy: 0.9787
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.9787
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 1.0000
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0982 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 0.9787
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0364 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0842 - accuracy: 0.9787
# Epoch 108/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1001 - accuracy: 0.9362
# Epoch 109/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0644 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 111/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9787
# Epoch 113/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.9787
# Epoch 116/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0365 - accuracy: 0.9787
# Epoch 117/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1054 - accuracy: 0.9574
# Epoch 118/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9787
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 120/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0580 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0229 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0416 - accuracy: 0.9787
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1386 - accuracy: 0.9574
# Epoch 131/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0284 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 1.0000
# Epoch 135/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 136/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0763 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 139/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0547 - accuracy: 0.9787
# Epoch 140/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9787
# Epoch 141/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0534 - accuracy: 0.9787
# Epoch 142/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 144/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0718 - accuracy: 0.9574
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 1.0000
# Epoch 147/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9787
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 150/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 154/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 156/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9574
# Epoch 157/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 165/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 166/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 168/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2009 - accuracy: 0.9149
# Epoch 172/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0459 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0655 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0350 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9787
# Epoch 177/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0406 - accuracy: 0.9787
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0591 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0324 - accuracy: 0.9787
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0288 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0398 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 188/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0153 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0199 - accuracy: 1.0000
# Epoch 192/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0835 - accuracy: 0.9787
# Epoch 200/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9787
# model created

# %% [markdown]
# ##Predict the response

# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import pickle
import numpy as np

from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('/content/Chat bot/intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))
